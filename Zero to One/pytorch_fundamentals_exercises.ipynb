# %% [markdown]
# # PyTorch Fundamentals - Comprehensive Exercises
#
# **Based on**: [Learn PyTorch - 00. PyTorch Fundamentals](https://www.learnpytorch.io/00_pytorch_fundamentals/)
#
# This notebook contains exercises from **Easy → Medium → Difficult** to master PyTorch fundamentals.
#
# ## 📚 Topics Covered
# 1. Introduction to Tensors
# 2. Creating Tensors
# 3. Tensor Operations
# 4. Matrix Multiplication
# 5. Tensor Shapes & Reshaping
# 6. Indexing & Slicing
# 7. PyTorch & NumPy
# 8. Reproducibility
# 9. GPU Operations
#
# ---

# %% [markdown]
# ## Setup

# %%
import torch
import numpy as np

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %% [markdown]
# ---
# ## Part 1: Introduction to Tensors
#
# ### What are Tensors?
# Tensors are the fundamental building blocks of machine learning. They represent data in numerical form.
#
# **Tensor Dimensions:**
# - **Scalar** (0D): A single number → `7`
# - **Vector** (1D): An array of numbers → `[1, 2, 3]`
# - **Matrix** (2D): A 2D array → `[[1, 2], [3, 4]]`
# - **Tensor** (3D+): Multi-dimensional arrays → `[[[1, 2], [3, 4]], [[5, 6], [7, 8]]]`
